# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
IBM = pd.read_csv(r'C:\Users\XPS\Documents\Python\Jedha\jedha\S1_python\Exercice\Sources\IBM_HR_ATTRITION.csv')
IBM['Attrition'] = IBM.Attrition.apply(lambda x: 1 if x == 'Yes' else 0)

# %%
sns.lmplot(x = 'DistanceFromHome', y = 'Attrition', data = IBM, logistic = True)

# %%
sns.lmplot(x = 'YearsWithCurrManager', y = 'Attrition', data = IBM, logistic = True)

# %%
sns.lmplot(x = 'YearsAtCompany', y = 'Attrition', data = IBM, logistic = True)

# %%
sns.lmplot(x = 'Age', y = 'MonthlyIncome', data = IBM)
