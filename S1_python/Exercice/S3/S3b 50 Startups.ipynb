# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
st50 = pd.read_csv(r'C:\Users\XPS\Documents\Python\Jedha\jedha\S1_python\Exercice\Sources\50_startups.csv')

# %%
st50.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %% [markdown]
# 2. Avez-vous des valeurs NaN dans le dataset ?

# %%
st50.isna().any()
# Out:
# R&D Spend          False
# Administration     False
# Marketing Spend    False
# State              False
# Profit             False
# dtype: bool

# %%
sns.relplot(x = 'R&D Spend', y = 'Profit', data = st50)
plt.xticks(rotation = 60)
# Out:
# (array([-25000.,      0.,  25000.,  50000.,  75000., 100000., 125000.,
#         150000., 175000.]), <a list of 9 Text xticklabel objects>)

# %% [markdown]
# 4. Faites de même avec les autres variables quantitatives

# %%
sns.relplot(x = 'Administration', y = 'Profit', data = st50)
plt.xticks(rotation = 60)
# Out:
# (array([ 40000.,  60000.,  80000., 100000., 120000., 140000., 160000.,
#         180000., 200000.]), <a list of 9 Text xticklabel objects>)

# %%
sns.relplot(x = 'Marketing Spend', y = 'Profit', data = st50)
plt.xticks(rotation = 60)
# Out:
# (array([-100000.,       0.,  100000.,  200000.,  300000.,  400000.,
#          500000.]), <a list of 7 Text xticklabel objects>)

# %%
sns.boxplot(x = 'State', y = 'Profit', data = st50)

# %%
sns.barplot(x = 'State', y = 'Profit', data = st50)

# %% [markdown]
# 7. Faites une heatmap qui va vous permettre de regarder la corrélation entre les variables. Que pouvez-vous conclure sur les variables les plus influentes sur le profit ?

# %%
sns.heatmap(st50.corr(), annot = True)

# %%
sns.relplot(x = 'R&D Spend', y = 'Administration', data = st50, hue = 'State')
sns.lmplot(x = 'R&D Spend', y = 'Administration', data = st50, hue = 'State')

# %%
sns.relplot(x = 'Marketing Spend', y = 'Administration', data = st50, hue = 'State')
sns.lmplot(x = 'Marketing Spend', y = 'Administration', data = st50, hue = 'State')
