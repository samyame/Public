# %% [markdown]
# https://julie.jedha.co/courses/jedha-full-stack-24-program/S0.3%20--%20Data%20Visualisation%20-%20Utilisation%20Seaborn%20%26%20Matplotlib/S3-B%20-%20Pratique%20de%20Seaborn%20Exercices/Exercices/6.%20Social%20Network%20Ads%20-%20Exercice.ipynb

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
social = pd.read_csv(r'C:\Users\XPS\Documents\Python\Jedha\jedha\S1_python\Exercice\Sources\Social_Network_Ads.csv')
social.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
sns.distplot(social.Age)

# %%
sns.distplot(social.EstimatedSalary)

# %%
social.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %% [markdown]
# Tentons quelque chose de nouveau. En général, on aime bien normaliser les données lorsque l'on fait du machine Learning. Tentons de le faire à la main. Créez une nouvelle colonne dans votre DataFrame dans laquelle vous ferez l'opération suivante :
#
# (x - u )/ s
#
# - x = une observation
#
# - u = la moyenne de votre échantillon
#
# - s = l'écart-type de votre échantillon

# %%
social['Norm_salary'] = (social.EstimatedSalary-social.EstimatedSalary.mean())/social.EstimatedSalary.std()

# %%
sns.distplot(social.Norm_salary)

# %% [markdown]
# 6. Filtrez uniquement les personnes de votre dataset qui ont cliqués sur la publicité

# %%
social2 = social[social.Purchased == 1]
social2
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased  Norm_salary
# 7    15694829  Female   32           150000          1     2.353802
# 16   15733883    Male   47            25000          1    -1.312214
# 17   15617482    Male   45            26000          1    -1.282886
# 18   15704583    Male   46            28000          1    -1.224229
# 19   15621083  Female   48            29000          1    -1.194901
# ..        ...     ...  ...              ...        ...          ...
# 393  15635893    Male   60            42000          1    -0.813636
# 395  15691863  Female   46            41000          1    -0.842964
# 396  15706071    Male   51            23000          1    -1.370870
# 397  15654296  Female   50            20000          1    -1.458854
# 399  15594041  Female   49            36000          1    -0.989604
#
# [143 rows x 6 columns]

# %%
sns.distplot(social2.Age)

# %%
sns.distplot(social2.EstimatedSalary)

# %% [markdown]
# https://julie.jedha.co/courses/jedha-full-stack-24-program/S0.3%20--%20Data%20Visualisation%20-%20Utilisation%20Seaborn%20%26%20Matplotlib/S3-B%20-%20Pratique%20de%20Seaborn%20Exercices/Exercices/6.%20Social%20Network%20Ads%20-%20Exercice.ipynb

# %%
social2.Gender.value_counts(normalize = True)
# Out:
# Female    0.538462
# Male      0.461538
# Name: Gender, dtype: float64

# %%
social.Gender.value_counts(normalize = True)
# Out:
# Female    0.51
# Male      0.49
# Name: Gender, dtype: float64

# %%
sns.lmplot(y = 'Purchased', x = 'Age', data = social, logistic = True)

# %%
sns.lmplot(y = 'Purchased', x = 'EstimatedSalary', data = social, logistic = True)

# %%
sns.lmplot(y = 'Purchased', x = 'Norm_salary', data = social, logistic = True)

# %% [markdown]
# Purchased are positively correlated with age and income regardless of gender
