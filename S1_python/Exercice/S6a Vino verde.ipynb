# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('winequality-red.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
for i in df.columns[:-1]:
    sns.lineplot(x = i, y ='quality', data = df)
    plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
Y = df[['quality']]
X = df.drop(['quality'],axis = 1)

X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size = 0.3, random_state = 42, stratify = Y)

sc = StandardScaler().fit(X_train)

X_trans = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression

log = LogisticRegression()

log.fit(X_trans,Y_train)
# Out:
# C:\Users\tashi\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\tashi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
# ...

# %%
log.score(X_trans,Y_train)
# Out:
# 0.6094727435210009

# %%
log.score(X_test,Y_test)
# Out:
# 0.6041666666666666

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(log, X_trans,Y_train, cv = 10).mean()
# Out:
# C:\Users\tashi\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:667: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   % (min_groups, self.n_splits)), UserWarning)
# C:\Users\tashi\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\tashi\anaconda3\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\tashi\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
from sklearn import metrics
y_pred = log.predict(X_test)

cm = metrics.confusion_matrix(Y_test, y_pred)
sns.heatmap(cm, annot=True)

# %%
sns.barplot(x = 'quality', y ='count', data = df2)

# %%
df2 = pd.DataFrame(df.groupby(['quality'])['pH'].count()).reset_index()
df2 = df2.rename(columns = {'pH':'count'})

# %%
n5 = np.full((len(Y_test),1), 5)

cm = metrics.confusion_matrix(Y_test, n5)
sns.heatmap(cm, annot=True)

# %%
from sklearn.feature_selection import chi2
feature_importance = chi2(X,Y)
feature_importance
# Out:
# (array([1.12606524e+01, 1.55802891e+01, 1.30256651e+01, 4.12329474e+00,
#         7.52425579e-01, 1.61936036e+02, 2.75555798e+03, 2.30432045e-04,
#         1.54654736e-01, 4.55848775e+00, 4.64298922e+01]),
#  array([4.64500416e-02, 8.15035154e-03, 2.31394417e-02, 5.31804675e-01,
#         9.79968040e-01, 3.82728810e-33, 0.00000000e+00, 1.00000000e+00,
#         9.99526491e-01, 4.72096321e-01, 7.42403757e-09]))

# %%
pd.DataFrame(index = X.columns, data ={'chi2':feature_importance[0], 'p-value':feature_importance[1]}).sort_values(by = 'chi2', ascending = False)
# Out:
#                              chi2       p-value
# total sulfur dioxide  2755.557984  0.000000e+00
# free sulfur dioxide    161.936036  3.827288e-33
# alcohol                 46.429892  7.424038e-09
# volatile acidity        15.580289  8.150352e-03
# citric acid             13.025665  2.313944e-02
# fixed acidity           11.260652  4.645004e-02
# sulphates                4.558488  4.720963e-01
# residual sugar           4.123295  5.318047e-01
# chlorides                0.752426  9.799680e-01
# pH                       0.154655  9.995265e-01
# density                  0.000230  1.000000e+00
