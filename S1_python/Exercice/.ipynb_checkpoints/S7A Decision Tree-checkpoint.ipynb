# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\tashi\anaconda3\lib\site-packages (0.14)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install python-graphviz
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydotplus
# Out:
# Requirement already satisfied: pydotplus in c:\users\tashi\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\tashi\anaconda3\lib\site-packages (from pydotplus) (2.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('bl.txt', header = 0)

# %%
df.describe()
# Out:
#        left_weight  left_distance  right_weight  right_distance
# count   625.000000     625.000000    625.000000      625.000000
# mean      3.000000       3.000000      3.000000        3.000000
# std       1.415346       1.415346      1.415346        1.415346
# min       1.000000       1.000000      1.000000        1.000000
# 25%       2.000000       2.000000      2.000000        2.000000
# 50%       3.000000       3.000000      3.000000        3.000000
# 75%       4.000000       4.000000      4.000000        4.000000
# max       5.000000       5.000000      5.000000        5.000000

# %%
df.shape
# Out:
# (625, 5)

# %%
X = df.drop('balance', axis = 1)
Y = df[['balance']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.3, random_state = 42)

# %%
from sklearn.tree import DecisionTreeClassifier

dtc = DecisionTreeClassifier(criterion = 'gini')

# %%
dtc.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
import graphviz
from sklearn.tree import export_graphviz
dot_data = export_graphviz(dtc,out_file=None, feature_names = X.columns)
graph = graphviz.Source(dot_data)
graph

# %% [markdown]
# from sklearn import tree
# tree.plot_tree(dtc)
# plt.figure(figsize=(30,10))
# a = plot_tree(dtc,
#               feature_names=X.columns,
#               class_names=["B","L","R"],
#               filled=True,
#               rounded=True,
#               fontsize=14)

# %%
dtc1 = DecisionTreeClassifier(criterion = 'entropy')
dtc1.fit(X_train,Y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='entropy',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
plt.figure(figsize=(30,10))
a = plot_tree(dtc1, 
              feature_names=X.columns, 
              class_names=["B","L","R"], 
              filled=True, 
              rounded=True, 
              fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-5b223d159d73> in <module>
#       1 plt.figure(figsize=(30,10))
# ----> 2 a = plot_tree(dtc1,
#       3               feature_names=X.columns,
#       4               class_names=["B","L","R"],
#       5               filled=True,
#
# NameError: name 'plot_tree' is not defined

# %%
X_train.reset_index()[(X_train.reset_index().left_weight == 4) & (X_train.reset_index().left_distance == 4) & (X_train.reset_index().right_weight == 3) & (X_train.reset_index().right_distance == 3)]
# Out:
#     index  left_weight  left_distance  right_weight  right_distance
# 67    462            4              4             3               3

# %%
ypred = dtc.predict(X_test)
ypred
# Out:
# array(['B', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'B', 'L',
#        'R', 'L', 'L', 'R', 'R', 'R', 'L', 'B', 'R', 'R', 'L', 'L', 'L',
#        'B', 'L', 'L', 'L', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L',
#        'B', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'L', 'L',
#        'R', 'R', 'L', 'L', 'L', 'L', 'L', 'R', 'L', 'L', 'R', 'R', 'L',
#        'L', 'L', 'R', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'R',
#        'L', 'L', 'R', 'L', 'R', 'L', 'B', 'L', 'L', 'L', 'R', 'L', 'L',
#        'L', 'R', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'B', 'R',
#        'L', 'L', 'L', 'R', 'R', 'L', 'R', 'B', 'R', 'R', 'L', 'R', 'L',
#        'L', 'L', 'B', 'L', 'R', 'L', 'R', 'R', 'R', 'B', 'R', 'L', 'R',
#        'L', 'L', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'L', 'B', 'R',
#        'R', 'B', 'R', 'R', 'L', 'R', 'R', 'R', 'R', 'R', 'B', 'L', 'R',
#        'L', 'L', 'L', 'L', 'L', 'R', 'R', 'B', 'L', 'L', 'R', 'L', 'L',
#        'R', 'L', 'R', 'R', 'R', 'L', 'L', 'L', 'L', 'R', 'L', 'R', 'R',
#        'L', 'R', 'L', 'R', 'R', 'L'], dtype=object)

# %%
y1pred = dtc1.predict(X_test)
y1pred
# Out:
# array(['B', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'L', 'R', 'L', 'B', 'L',
#        'R', 'L', 'L', 'R', 'R', 'R', 'L', 'B', 'R', 'R', 'L', 'L', 'L',
#        'R', 'L', 'L', 'L', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'L', 'L',
#        'B', 'L', 'R', 'R', 'L', 'R', 'L', 'L', 'R', 'L', 'R', 'L', 'L',
#        'R', 'R', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'R', 'R', 'L',
#        'L', 'L', 'R', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'R',
#        'L', 'L', 'R', 'L', 'R', 'L', 'B', 'L', 'L', 'L', 'R', 'L', 'L',
#        'L', 'R', 'L', 'L', 'R', 'R', 'R', 'R', 'R', 'L', 'L', 'B', 'R',
#        'L', 'L', 'L', 'R', 'R', 'L', 'R', 'L', 'R', 'R', 'L', 'R', 'L',
#        'L', 'L', 'B', 'R', 'R', 'L', 'R', 'R', 'R', 'B', 'R', 'L', 'R',
#        'L', 'L', 'L', 'R', 'L', 'R', 'L', 'R', 'L', 'L', 'B', 'B', 'R',
#        'R', 'B', 'R', 'R', 'L', 'R', 'R', 'R', 'R', 'R', 'B', 'L', 'R',
#        'L', 'L', 'R', 'L', 'L', 'R', 'R', 'B', 'L', 'L', 'R', 'B', 'R',
#        'R', 'L', 'R', 'R', 'R', 'R', 'L', 'L', 'L', 'R', 'L', 'R', 'R',
#        'L', 'R', 'L', 'R', 'R', 'L'], dtype=object)

# %%
L = []
for i in range(len(X_test)):
    if ypred[i] == y1pred[i]:
        L.append(True)
    else:
        L.append(False)

# %%
from collections import Counter
Counter(L)
# Out:
# Counter({True: 179, False: 9})

# %%
dtc.score(X_test,Y_test)
# Out:
# 0.776595744680851

# %%
dtc1.score(X_test,Y_test)
# Out:
# 0.7872340425531915

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(Y_test, ypred)
sns.heatmap(cm, annot=True, fmt="d")
